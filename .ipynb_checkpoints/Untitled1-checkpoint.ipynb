# %%
# this code is generated by the Domino Code Assist toolbar button
import domino_code_assist as dca
dca.init()
# Out:
# Cannot show ipywidgets in text

# %%
# !pip install azure-storage-blob azure-identity --user
# Out:
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (/opt/conda/lib/python3.9/site-packages)
# ...
#   Using cached azure_storage_blob-12.19.0-py3-none-any.whl (394 kB)
# ...
#   Using cached azure_identity-1.15.0-py3-none-any.whl (164 kB)
# ...
#   Using cached azure_core-1.30.0-py3-none-any.whl (193 kB)
# ...
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# ...
#   Using cached msal-1.26.0-py2.py3-none-any.whl (99 kB)
# ...
#   Using cached msal_extensions-1.1.0-py3-none-any.whl (19 kB)
# ...
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# ...
#   Using cached portalocker-2.8.2-py3-none-any.whl (17 kB)
# ...
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (/opt/conda/lib/python3.9/site-packages)
# ...

# %%
import os, uuid
from azure.identity import DefaultAzureCredential
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient

try:
    print("Azure Blob Storage Python quickstart sample")

    # Quickstart code goes here

except Exception as ex:
    print('Exception:')
    print(ex)
# Out:
# Azure Blob Storage Python quickstart sample

# %%
account_url = "https://gskdmm.blob.core.windows.net"

connect_str="DefaultEndpointsProtocol=https;AccountName=gskdmm;AccountKey=sYefYYpbKHy9IAVN7lAMRABmgPJgiK/h+/k/dRF5jgCkULBm2fe9QNgTSXRUtbNzhhzg4EX6e3By+AStJg/yKQ==;EndpointSuffix=core.windows.net"

blob_service_client = BlobServiceClient.from_connection_string(connect_str)

# %%
# Create a unique name for the container
container_name = str(uuid.uuid4())

# Create the container
container_client = blob_service_client.create_container(container_name)

# %%
# Create a file in the local data directory to upload and download
local_file_name = str(uuid.uuid4()) + ".txt"
upload_file_path = os.path.join(local_path, local_file_name)

# Write text to the file
file = open(file=upload_file_path, mode='w')
file.write("Hello, World!")
file.close()

# Create a blob client using the local file name as the name for the blob
blob_client = blob_service_client.get_blob_client(container=container_name, blob=local_file_name)

print("\nUploading to Azure Storage as blob:\n\t" + local_file_name)

# Upload the created file
with open(file=upload_file_path, mode="rb") as data:
    blob_client.upload_blob(data)
# Out:
# Uploading to Azure Storage as blob:
# 	f5f9209e-7371-4e21-b9ce-2bf4f09fb206.txt

# %%
print("\nListing blobs...")

# List the blobs in the container
blob_list = container_client.list_blobs()
for blob in blob_list:
    print("\t" + blob.name)
# Out:
# Listing blobs...
# 	f5f9209e-7371-4e21-b9ce-2bf4f09fb206.txt
